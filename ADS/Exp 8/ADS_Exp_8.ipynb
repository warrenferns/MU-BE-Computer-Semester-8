# %% [markdown]
# https://machinelearningmastery.com/time-series-prediction-lstm-recurrent-neural-networks-python-keras/

# %%
import pandas
import matplotlib.pyplot as plt
dataset = pandas.read_csv('airline-passengers.csv', usecols=[1], engine='python')
plt.plot(dataset)
plt.show()

# %%
import tensorflow

# %%
tensorflow.__version__
# Out:
# '2.12.0'

# %%
#!pip install tensorflow

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
# fix random seed for reproducibility
tf.random.set_seed(7)

# %%
# load the dataset
dataframe = pd.read_csv('airline-passengers.csv', usecols=[1], engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')

# %%
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# %%
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(len(train), len(test))
# Out:
# 96 48

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return np.array(dataX), np.array(dataY)

# %%
# reshape into X=t and Y=t+1
look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# %%
# reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
# create and fit the LSTM network
trainX
# Out:
# array([[[0.01544401]],
#
#        [[0.02702703]],
#
#        [[0.05405405]],
#
#        [[0.04826255]],
#
#        [[0.03281853]],
#
#        [[0.05984557]],
#
#        [[0.08494207]],
#
#        [[0.08494207]],
#
#        [[0.06177607]],
#
#        [[0.02895753]],
#
#        [[0.        ]],
#
#        [[0.02702703]],
#
#        [[0.02123553]],
#
#        [[0.04247104]],
#
#        [[0.07142857]],
#
#        [[0.05984557]],
#
#        [[0.04054055]],
#
#        [[0.08687258]],
#
#        [[0.12741312]],
#
#        [[0.12741312]],
#
#        [[0.10424709]],
#
#        [[0.05598456]],
#
#        [[0.01930502]],
#
#        [[0.06949806]],
#
#        [[0.07915059]],
#
#        [[0.08880308]],
#
#        [[0.14285713]],
#
#        [[0.11389962]],
#
#        [[0.13127413]],
#
#        [[0.14285713]],
#
#        [[0.18339768]],
#
#        [[0.18339768]],
#
#        [[0.15444016]],
#
#        [[0.11196911]],
#
#        [[0.08108109]],
#
#        [[0.1196911 ]],
#
#        [[0.12934363]],
#
#        [[0.14671814]],
#
#        [[0.17181468]],
#
#        [[0.14864865]],
#
#        [[0.15250966]],
#
#        [[0.22007722]],
#
#        [[0.24324325]],
#
#        [[0.26640925]],
#
#        [[0.2027027 ]],
#
#        [[0.16795367]],
#
#        [[0.13127413]],
#
#        [[0.17374519]],
#
#        [[0.17760617]],
#
#        [[0.17760617]],
#
#        [[0.25482625]],
#
#        [[0.25289574]],
#
#        [[0.24131274]],
#
#        [[0.26833975]],
#
#        [[0.3088803 ]],
#
#        [[0.32432434]],
#
#        [[0.25675675]],
#
#        [[0.20656371]],
#
#        [[0.14671814]],
#
#        [[0.18725869]],
#
#        [[0.19305018]],
#
#        [[0.16216215]],
#
#        [[0.25289574]],
#
#        [[0.23745173]],
#
#        [[0.25096524]],
#
#        [[0.3088803 ]],
#
#        [[0.38223937]],
#
#        [[0.36486486]],
#
#        [[0.2992278 ]],
#
#        [[0.24131274]],
#
#        [[0.1911197 ]],
#
#        [[0.24131274]],
#
#        [[0.26640925]],
#
#        [[0.24903473]],
#
#        [[0.31467178]],
#
#        [[0.3185328 ]],
#
#        [[0.32046333]],
#
#        [[0.4073359 ]],
#
#        [[0.5019305 ]],
#
#        [[0.46911195]],
#
#        [[0.40154442]],
#
#        [[0.32818535]],
#
#        [[0.25675675]],
#
#        [[0.3359073 ]],
#
#        [[0.34749034]],
#
#        [[0.33397684]],
#
#        [[0.41119692]],
#
#        [[0.4034749 ]],
#
#        [[0.4131274 ]],
#
#        [[0.52123547]],
#
#        [[0.5965251 ]],
#
#        [[0.58108103]],
#
#        [[0.484556  ]],
#
#        [[0.3899614 ]]], dtype=float32)

# %%
model = Sequential([
                  LSTM(units=4,input_shape=(1,1),activation="relu"), 
                  Dense(units=1,activation="softmax"), 
])

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 4)                 96
#
#  dense_1 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 101
# Trainable params: 101
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
# 94/94 - 2s - loss: 0.6397 - 2s/epoch - 17ms/step
# Epoch 2/100
# 94/94 - 0s - loss: 0.6397 - 187ms/epoch - 2ms/step
# Epoch 3/100
# 94/94 - 0s - loss: 0.6397 - 281ms/epoch - 3ms/step
# Epoch 4/100
# 94/94 - 0s - loss: 0.6397 - 247ms/epoch - 3ms/step
# Epoch 5/100
# 94/94 - 0s - loss: 0.6397 - 188ms/epoch - 2ms/step
# Epoch 6/100
# 94/94 - 0s - loss: 0.6397 - 187ms/epoch - 2ms/step
# Epoch 7/100
# 94/94 - 0s - loss: 0.6397 - 172ms/epoch - 2ms/step
# Epoch 8/100
# 94/94 - 0s - loss: 0.6397 - 173ms/epoch - 2ms/step
# Epoch 9/100
# 94/94 - 0s - loss: 0.6397 - 186ms/epoch - 2ms/step
# Epoch 10/100
# 94/94 - 0s - loss: 0.6397 - 187ms/epoch - 2ms/step
# Epoch 11/100
# 94/94 - 0s - loss: 0.6397 - 188ms/epoch - 2ms/step
# Epoch 12/100
# 94/94 - 0s - loss: 0.6397 - 190ms/epoch - 2ms/step
# Epoch 13/100
# 94/94 - 0s - loss: 0.6397 - 169ms/epoch - 2ms/step
# Epoch 14/100
# 94/94 - 0s - loss: 0.6397 - 172ms/epoch - 2ms/step
# Epoch 15/100
# 94/94 - 0s - loss: 0.6397 - 172ms/epoch - 2ms/step
# Epoch 16/100
# 94/94 - 0s - loss: 0.6397 - 219ms/epoch - 2ms/step
# Epoch 17/100
# 94/94 - 0s - loss: 0.6397 - 266ms/epoch - 3ms/step
# Epoch 18/100
# 94/94 - 0s - loss: 0.6397 - 203ms/epoch - 2ms/step
# Epoch 19/100
# 94/94 - 0s - loss: 0.6397 - 203ms/epoch - 2ms/step
# Epoch 20/100
# 94/94 - 0s - loss: 0.6397 - 172ms/epoch - 2ms/step
# Epoch 21/100
# 94/94 - 0s - loss: 0.6397 - 188ms/epoch - 2ms/step
# Epoch 22/100
# 94/94 - 0s - loss: 0.6397 - 234ms/epoch - 2ms/step
# Epoch 23/100
# 94/94 - 0s - loss: 0.6397 - 170ms/epoch - 2ms/step
# Epoch 24/100
# 94/94 - 0s - loss: 0.6397 - 188ms/epoch - 2ms/step
# Epoch 25/100
# 94/94 - 0s - loss: 0.6397 - 187ms/epoch - 2ms/step
# Epoch 26/100
# 94/94 - 0s - loss: 0.6397 - 170ms/epoch - 2ms/step
# Epoch 27/100
# 94/94 - 0s - loss: 0.6397 - 188ms/epoch - 2ms/step
# Epoch 28/100
# 94/94 - 0s - loss: 0.6397 - 173ms/epoch - 2ms/step
# Epoch 29/100
# 94/94 - 0s - loss: 0.6397 - 339ms/epoch - 4ms/step
# Epoch 30/100
# 94/94 - 0s - loss: 0.6397 - 340ms/epoch - 4ms/step
# Epoch 31/100
# 94/94 - 0s - loss: 0.6397 - 219ms/epoch - 2ms/step
# Epoch 32/100
# 94/94 - 0s - loss: 0.6397 - 172ms/epoch - 2ms/step
# Epoch 33/100
# 94/94 - 0s - loss: 0.6397 - 203ms/epoch - 2ms/step
# Epoch 34/100
# 94/94 - 0s - loss: 0.6397 - 189ms/epoch - 2ms/step
# Epoch 35/100
# 94/94 - 0s - loss: 0.6397 - 171ms/epoch - 2ms/step
# Epoch 36/100
# 94/94 - 0s - loss: 0.6397 - 188ms/epoch - 2ms/step
# Epoch 37/100
# 94/94 - 0s - loss: 0.6397 - 187ms/epoch - 2ms/step
# Epoch 38/100
# 94/94 - 0s - loss: 0.6397 - 172ms/epoch - 2ms/step
# Epoch 39/100
# 94/94 - 0s - loss: 0.6397 - 171ms/epoch - 2ms/step
# Epoch 40/100
# 94/94 - 0s - loss: 0.6397 - 170ms/epoch - 2ms/step
# Epoch 41/100
# 94/94 - 0s - loss: 0.6397 - 186ms/epoch - 2ms/step
# Epoch 42/100
# 94/94 - 0s - loss: 0.6397 - 173ms/epoch - 2ms/step
# Epoch 43/100
# 94/94 - 0s - loss: 0.6397 - 172ms/epoch - 2ms/step
# Epoch 44/100
# 94/94 - 0s - loss: 0.6397 - 173ms/epoch - 2ms/step
# Epoch 45/100
# 94/94 - 0s - loss: 0.6397 - 170ms/epoch - 2ms/step
# Epoch 46/100
# 94/94 - 0s - loss: 0.6397 - 171ms/epoch - 2ms/step
# Epoch 47/100
# 94/94 - 0s - loss: 0.6397 - 188ms/epoch - 2ms/step
# Epoch 48/100
# 94/94 - 0s - loss: 0.6397 - 187ms/epoch - 2ms/step
# Epoch 49/100
# 94/94 - 0s - loss: 0.6397 - 172ms/epoch - 2ms/step
# Epoch 50/100
# 94/94 - 0s - loss: 0.6397 - 173ms/epoch - 2ms/step
# Epoch 51/100
# 94/94 - 0s - loss: 0.6397 - 172ms/epoch - 2ms/step
# Epoch 52/100
# 94/94 - 0s - loss: 0.6397 - 187ms/epoch - 2ms/step
# Epoch 53/100
# 94/94 - 0s - loss: 0.6397 - 187ms/epoch - 2ms/step
# Epoch 54/100
# 94/94 - 0s - loss: 0.6397 - 223ms/epoch - 2ms/step
# Epoch 55/100
# 94/94 - 0s - loss: 0.6397 - 191ms/epoch - 2ms/step
# Epoch 56/100
# 94/94 - 0s - loss: 0.6397 - 205ms/epoch - 2ms/step
# Epoch 57/100
# 94/94 - 0s - loss: 0.6397 - 168ms/epoch - 2ms/step
# Epoch 58/100
# 94/94 - 0s - loss: 0.6397 - 172ms/epoch - 2ms/step
# Epoch 59/100
# 94/94 - 0s - loss: 0.6397 - 172ms/epoch - 2ms/step
# Epoch 60/100
# 94/94 - 0s - loss: 0.6397 - 171ms/epoch - 2ms/step
# Epoch 61/100
# 94/94 - 0s - loss: 0.6397 - 173ms/epoch - 2ms/step
# Epoch 62/100
# 94/94 - 0s - loss: 0.6397 - 171ms/epoch - 2ms/step
# Epoch 63/100
# 94/94 - 0s - loss: 0.6397 - 187ms/epoch - 2ms/step
# Epoch 64/100
# 94/94 - 0s - loss: 0.6397 - 158ms/epoch - 2ms/step
# Epoch 65/100
# 94/94 - 0s - loss: 0.6397 - 156ms/epoch - 2ms/step
# Epoch 66/100
# 94/94 - 0s - loss: 0.6397 - 171ms/epoch - 2ms/step
# Epoch 67/100
# 94/94 - 0s - loss: 0.6397 - 172ms/epoch - 2ms/step
# Epoch 68/100
# 94/94 - 0s - loss: 0.6397 - 266ms/epoch - 3ms/step
# Epoch 69/100
# 94/94 - 0s - loss: 0.6397 - 231ms/epoch - 2ms/step
# Epoch 70/100
# 94/94 - 0s - loss: 0.6397 - 216ms/epoch - 2ms/step
# Epoch 71/100
# 94/94 - 0s - loss: 0.6397 - 231ms/epoch - 2ms/step
# Epoch 72/100
# 94/94 - 0s - loss: 0.6397 - 171ms/epoch - 2ms/step
# Epoch 73/100
# 94/94 - 0s - loss: 0.6397 - 188ms/epoch - 2ms/step
# Epoch 74/100
# 94/94 - 0s - loss: 0.6397 - 262ms/epoch - 3ms/step
# Epoch 75/100
# 94/94 - 0s - loss: 0.6397 - 258ms/epoch - 3ms/step
# Epoch 76/100
# 94/94 - 0s - loss: 0.6397 - 218ms/epoch - 2ms/step
# Epoch 77/100
# 94/94 - 0s - loss: 0.6397 - 203ms/epoch - 2ms/step
# Epoch 78/100
# 94/94 - 0s - loss: 0.6397 - 196ms/epoch - 2ms/step
# Epoch 79/100
# 94/94 - 0s - loss: 0.6397 - 190ms/epoch - 2ms/step
# Epoch 80/100
# 94/94 - 0s - loss: 0.6397 - 189ms/epoch - 2ms/step
# Epoch 81/100
# 94/94 - 0s - loss: 0.6397 - 242ms/epoch - 3ms/step
# Epoch 82/100
# 94/94 - 0s - loss: 0.6397 - 227ms/epoch - 2ms/step
# Epoch 83/100
# 94/94 - 0s - loss: 0.6397 - 226ms/epoch - 2ms/step
# Epoch 84/100
# 94/94 - 0s - loss: 0.6397 - 212ms/epoch - 2ms/step
# Epoch 85/100
# 94/94 - 0s - loss: 0.6397 - 225ms/epoch - 2ms/step
# Epoch 86/100
# 94/94 - 0s - loss: 0.6397 - 209ms/epoch - 2ms/step
# Epoch 87/100
# 94/94 - 0s - loss: 0.6397 - 183ms/epoch - 2ms/step
# Epoch 88/100
# 94/94 - 0s - loss: 0.6397 - 172ms/epoch - 2ms/step
# Epoch 89/100
# 94/94 - 0s - loss: 0.6397 - 156ms/epoch - 2ms/step
# Epoch 90/100
# 94/94 - 0s - loss: 0.6397 - 172ms/epoch - 2ms/step
# Epoch 91/100
# 94/94 - 0s - loss: 0.6397 - 172ms/epoch - 2ms/step
# Epoch 92/100
# 94/94 - 0s - loss: 0.6397 - 186ms/epoch - 2ms/step
# Epoch 93/100
# 94/94 - 0s - loss: 0.6397 - 172ms/epoch - 2ms/step
# Epoch 94/100
# 94/94 - 0s - loss: 0.6397 - 172ms/epoch - 2ms/step
# Epoch 95/100
# 94/94 - 0s - loss: 0.6397 - 172ms/epoch - 2ms/step
# Epoch 96/100
# 94/94 - 0s - loss: 0.6397 - 223ms/epoch - 2ms/step
# Epoch 97/100
# 94/94 - 0s - loss: 0.6397 - 213ms/epoch - 2ms/step
# Epoch 98/100
# 94/94 - 0s - loss: 0.6397 - 203ms/epoch - 2ms/step
# Epoch 99/100
# 94/94 - 0s - loss: 0.6397 - 179ms/epoch - 2ms/step
# Epoch 100/100
# 94/94 - 0s - loss: 0.6397 - 174ms/epoch - 2ms/step

# %%
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# 3/3 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 0s/step
# Train Score: 414.30 RMSE
# Test Score: 220.98 RMSE

# %%
# shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
